# %% [markdown]
# <a href="https://colab.research.google.com/github/sakshisinghal936/DA-weekday-batch/blob/main/Pandas_class24.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv("/content/List of Countries by Sugarcane Production.csv")

df
# Out:
#      Unnamed: 0    Country      Continent Production (Tons)  \
# 0             0     Brazil  South America       768.678.382
# 1             1      India           Asia       348.448.000
# 2             2      China           Asia       123.059.739
# 3             3   Thailand           Asia        87.468.496
# 4             4   Pakistan           Asia        65.450.704
# ..          ...        ...            ...               ...
# 98           98    Lebanon           Asia                97
# 99           99   Djibouti         Africa                53
# 100         100  Singapore           Asia                50
# 101         101      Samoa        Oceania                12
# 102         102      Syria           Asia                 1
#
#     Production per Person (Kg) Acreage (Hectare) Yield (Kg / Hectare)
# 0                    3.668,531        10.226.205             75.167,5
# 1                       260721         4.950.000             70.393,5
# 2                        88287         1.675.215             73.459,1
# 3                    1.264,303         1.336.575             65.442,2
# 4                       324219         1.130.820               57.879
# ..                         ...               ...                  ...
# 98                          16                 3             28.386,4
# 99                          51               NaN                  NaN
# 100                          9                 2                   25
# 101                          6                 1             11.949,8
# 102                          0                 0             83.034,2
#
# [103 rows x 7 columns]

# %%
# !git clone "https://github.com/sakshisinghal936/Datasets"
# Out:
# Cloning into 'Datasets'...
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 6 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (6/6), 1.15 MiB | 3.59 MiB/s, done.

# %%
# !git clone "https://github.com/sakshisinghal936/Datasets/blob/main/songs.csv"
# Out:
# Cloning into 'songs.csv'...
# fatal: repository 'https://github.com/sakshisinghal936/Datasets/blob/main/songs.csv/' not found

# %%
# !git clone "https://github.com/sakshisinghal936/DA-weekday-batch"
# Out:
# Cloning into 'DA-weekday-batch'...
# remote: Enumerating objects: 214, done.
# remote: Counting objects: 100% (54/54), done.
# remote: Compressing objects: 100% (44/44), done.
# remote: Total 214 (delta 34), reused 9 (delta 9), pack-reused 160 (from 1)
# Receiving objects: 100% (214/214), 21.29 MiB | 19.64 MiB/s, done.
# Resolving deltas: 100% (83/83), done.

# %%
df1 = pd.read_csv("/content/DA-weekday-batch/myntra_data.csv")
df1
# Out:
#                               product_name      brand_name  rating  \
# 0            Croc Textured Two Fold Wallet     Lino Perros     0.0
# 1                      Men Striped Sliders  Mast & Harbour     4.0
# 2                     Printed A-line Kurta            Biba     4.3
# 3             Girls Floral Printed T-shirt        Anthrilo     0.0
# 4           Women Printed Kurta with Skirt    FASHION DWAR     0.0
# ...                                    ...             ...     ...
# 168024          Ethnic Motifs Kaftan Dress            Soch     0.0
# 168025  Leather Wedge Sandals with Tassels         fitflop     0.0
# 168026                 Leather Wedge Pumps         fitflop     0.0
# 168027      V015 Professional Hair Trimmer             VGR     0.0
# 168028                Women Open Toe Flats          daisie     0.0
#
#         rating_count  marked_price  discounted_price  \
# 0                  0          1295               828
# 1                 76          1299               584
# 2                 66          1999              1599
# 3                  0           599               539
# 4                  0          2899              2899
# ...              ...           ...               ...
# 168024             0          3998              3998
# 168025             0          6799              6799
# 168026             0          5999              5999
# 168027             0          2695               995
# 168028             0          1450              1377
#
#                                              product_link
# 0       wallets/lino-perros/lino-perros-women-peach-co...
# 1       flip-flops/mast--harbour/mast--harbour-men-nav...
# 2       kurtas/biba/biba-women-off-white--black-printe...
# 3       tshirts/anthrilo/anthrilo-girls-white-floral-p...
# 4       kurta-sets/fashion-dwar/fashion-dwar-women-mul...
# ...                                                   ...
# 168024  dresses/soch/soch-blue-ethnic-motifs-kaftan-dr...
# 168025  heels/fitflop/fitflop-tan-leather-wedge-sandal...
# 168026  heels/fitflop/fitflop-blue-leather-wedge-pumps...
# 168027  trimmer/vgr/vgr-men-v-015-professional-hair-tr...
# 168028  flats/daisie/daisie-women-grey-printed-open-to...
#
# [168029 rows x 7 columns]

# %%
df.head()
# Out:
#    Unnamed: 0   Country      Continent Production (Tons)  \
# 0           0    Brazil  South America       768.678.382
# 1           1     India           Asia       348.448.000
# 2           2     China           Asia       123.059.739
# 3           3  Thailand           Asia        87.468.496
# 4           4  Pakistan           Asia        65.450.704
#
#   Production per Person (Kg) Acreage (Hectare) Yield (Kg / Hectare)
# 0                  3.668,531        10.226.205             75.167,5
# 1                     260721         4.950.000             70.393,5
# 2                      88287         1.675.215             73.459,1
# 3                  1.264,303         1.336.575             65.442,2
# 4                     324219         1.130.820               57.879

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 7 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Unnamed: 0                  103 non-null    int64
#  1   Country                     103 non-null    object
#  2   Continent                   103 non-null    object
#  3   Production (Tons)           103 non-null    object
#  4   Production per Person (Kg)  103 non-null    object
#  5   Acreage (Hectare)           102 non-null    object
#  6   Yield (Kg / Hectare)        102 non-null    object
# dtypes: int64(1), object(6)
# memory usage: 5.8+ KB

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df
# Out:
#      Unnamed: 0    Country      Continent Production (Tons)  \
# 0             0     Brazil  South America       768.678.382
# 1             1      India           Asia       348.448.000
# 2             2      China           Asia       123.059.739
# 3             3   Thailand           Asia        87.468.496
# 4             4   Pakistan           Asia        65.450.704
# ..          ...        ...            ...               ...
# 98           98    Lebanon           Asia                97
# 99           99   Djibouti         Africa                53
# 100         100  Singapore           Asia                50
# 101         101      Samoa        Oceania                12
# 102         102      Syria           Asia                 1
#
#     Production per Person (Kg) Acreage (Hectare) Yield (Kg / Hectare)
# 0                    3.668,531        10.226.205             75.167,5
# 1                       260721         4.950.000             70.393,5
# 2                        88287         1.675.215             73.459,1
# 3                    1.264,303         1.336.575             65.442,2
# 4                       324219         1.130.820               57.879
# ..                         ...               ...                  ...
# 98                          16                 3             28.386,4
# 99                          51               NaN                  NaN
# 100                          9                 2                   25
# 101                          6                 1             11.949,8
# 102                          0                 0             83.034,2
#
# [103 rows x 7 columns]

# %%
df.head()
# Out:
#    Unnamed: 0   Country      Continent Production (Tons)  \
# 0           0    Brazil  South America       768.678.382
# 1           1     India           Asia       348.448.000
# 2           2     China           Asia       123.059.739
# 3           3  Thailand           Asia        87.468.496
# 4           4  Pakistan           Asia        65.450.704
#
#   Production per Person (Kg) Acreage (Hectare) Yield (Kg / Hectare)
# 0                  3.668,531        10.226.205             75.167,5
# 1                     260721         4.950.000             70.393,5
# 2                      88287         1.675.215             73.459,1
# 3                  1.264,303         1.336.575             65.442,2
# 4                     324219         1.130.820               57.879

# %%
df.tail(4)
# Out:
#      Unnamed: 0    Country Continent Production (Tons)  \
# 99           99   Djibouti    Africa                53
# 100         100  Singapore      Asia                50
# 101         101      Samoa   Oceania                12
# 102         102      Syria      Asia                 1
#
#     Production per Person (Kg) Acreage (Hectare) Yield (Kg / Hectare)
# 99                          51               NaN                  NaN
# 100                          9                 2                   25
# 101                          6                 1             11.949,8
# 102                          0                 0             83.034,2

# %%
df.shape
# Out:
# (103, 7)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Country', 'Continent', 'Production (Tons)',
#        'Production per Person (Kg)', 'Acreage (Hectare)',
#        'Yield (Kg / Hectare)'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Unnamed: 0                     int64
# Country                       object
# Continent                     object
# Production (Tons)             object
# Production per Person (Kg)    object
# Acreage (Hectare)             object
# Yield (Kg / Hectare)          object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 7 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Unnamed: 0                  103 non-null    int64
#  1   Country                     103 non-null    object
#  2   Continent                   103 non-null    object
#  3   Production (Tons)           103 non-null    object
#  4   Production per Person (Kg)  103 non-null    object
#  5   Acreage (Hectare)           102 non-null    object
#  6   Yield (Kg / Hectare)        102 non-null    object
# dtypes: int64(1), object(6)
# memory usage: 5.8+ KB

# %%
df.describe()
# Out:
#        Unnamed: 0
# count  103.000000
# mean    51.000000
# std     29.877528
# min      0.000000
# 25%     25.500000
# 50%     51.000000
# 75%     76.500000
# max    102.000000

# %%
df.head()
# Out:
#    Unnamed: 0   Country      Continent Production (Tons)  \
# 0           0    Brazil  South America       768.678.382
# 1           1     India           Asia       348.448.000
# 2           2     China           Asia       123.059.739
# 3           3  Thailand           Asia        87.468.496
# 4           4  Pakistan           Asia        65.450.704
#
#   Production per Person (Kg) Acreage (Hectare) Yield (Kg / Hectare)
# 0                  3.668,531        10.226.205             75.167,5
# 1                     260721         4.950.000             70.393,5
# 2                      88287         1.675.215             73.459,1
# 3                  1.264,303         1.336.575             65.442,2
# 4                     324219         1.130.820               57.879

# %%
df[df["Country"]=="India"]
# Out:
#    Unnamed: 0 Country Continent Production (Tons) Production per Person (Kg)  \
# 1           1   India      Asia       348.448.000                     260721
#
#   Acreage (Hectare) Yield (Kg / Hectare)
# 1         4.950.000             70.393,5

# %%
df[df["Country"]=="Pakistan"]
# Out:
#    Unnamed: 0   Country Continent Production (Tons)  \
# 4           4  Pakistan      Asia        65.450.704
#
#   Production per Person (Kg) Acreage (Hectare) Yield (Kg / Hectare)
# 4                     324219         1.130.820               57.879

# %%
df[df["Continent"]=="Asia"].shape
# Out:
# (25, 7)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                    0
# Country                       0
# Continent                     0
# Production (Tons)             0
# Production per Person (Kg)    0
# Acreage (Hectare)             1
# Yield (Kg / Hectare)          1
# dtype: int64

# %%
df.isna().sum()
# Out:
# Unnamed: 0                    0
# Country                       0
# Continent                     0
# Production (Tons)             0
# Production per Person (Kg)    0
# Acreage (Hectare)             1
# Yield (Kg / Hectare)          1
# dtype: int64

# %%
df[df["Acreage (Hectare)"].isnull()]
# Out:
#     Unnamed: 0   Country Continent Production (Tons)  \
# 99          99  Djibouti    Africa                53
#
#    Production per Person (Kg) Acreage (Hectare) Yield (Kg / Hectare)
# 99                         51               NaN                  NaN

# %%
df.shape
# Out:
# (103, 7)

# %%
df = df.dropna()

# %%
df_nullfilled = df.fillna("")
df_nullfilled
# Out:
#      Unnamed: 0    Country      Continent Production (Tons)  \
# 0             0     Brazil  South America       768.678.382
# 1             1      India           Asia       348.448.000
# 2             2      China           Asia       123.059.739
# 3             3   Thailand           Asia        87.468.496
# 4             4   Pakistan           Asia        65.450.704
# ..          ...        ...            ...               ...
# 98           98    Lebanon           Asia                97
# 99           99   Djibouti         Africa                53
# 100         100  Singapore           Asia                50
# 101         101      Samoa        Oceania                12
# 102         102      Syria           Asia                 1
#
#     Production per Person (Kg) Acreage (Hectare) Yield (Kg / Hectare)
# 0                    3.668,531        10.226.205             75.167,5
# 1                       260721         4.950.000             70.393,5
# 2                        88287         1.675.215             73.459,1
# 3                    1.264,303         1.336.575             65.442,2
# 4                       324219         1.130.820               57.879
# ..                         ...               ...                  ...
# 98                          16                 3             28.386,4
# 99                          51
# 100                          9                 2                   25
# 101                          6                 1             11.949,8
# 102                          0                 0             83.034,2
#
# [103 rows x 7 columns]

# %%
set(df["Continent"].values)
# Out:
# {'Africa', 'Asia', 'Europe', 'North America', 'Oceania', 'South America'}

# %%
df["Continent"].unique()
# Out:
# array(['South America', 'Asia', 'North America', 'Oceania', 'Africa',
#        'Europe'], dtype=object)

# %%
df["Continent"].nunique()
# Out:
# 6

# %%
  df["Continent"].value_counts()
# Out:
# Continent
# Africa           38
# Asia             25
# North America    22
# South America    11
# Oceania           4
# Europe            2
# Name: count, dtype: int64

# %%
df.sum()
# Out:
# Unnamed: 0                                                                 5154
# Country                       BrazilIndiaChinaThailandPakistanMexicoColombia...
# Continent                     South AmericaAsiaAsiaAsiaAsiaNorth AmericaSout...
# Production (Tons)             768.678.382348.448.000123.059.73987.468.49665....
# Production per Person (Kg)    3.668,531260721882871.264,30332421945252474007...
# Acreage (Hectare)             10.226.2054.950.0001.675.2151.336.5751.130.820...
# Yield (Kg / Hectare)          75.167,570.393,573.459,165.442,257.87972.2788....
# dtype: object

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df["Country"].duplicated().sum()
# Out:
# 0

# %%
df["Continent"].duplicated().sum()
# Out:
# 96

# %%
df.drop_duplicates(keep = False)
# Out:
#      Unnamed: 0    Country      Continent Production (Tons)  \
# 0             0     Brazil  South America       768.678.382
# 1             1      India           Asia       348.448.000
# 2             2      China           Asia       123.059.739
# 3             3   Thailand           Asia        87.468.496
# 4             4   Pakistan           Asia        65.450.704
# ..          ...        ...            ...               ...
# 97           97      Spain         Europe               394
# 98           98    Lebanon           Asia                97
# 100         100  Singapore           Asia                50
# 101         101      Samoa        Oceania                12
# 102         102      Syria           Asia                 1
#
#     Production per Person (Kg) Acreage (Hectare) Yield (Kg / Hectare)
# 0                    3.668,531        10.226.205             75.167,5
# 1                       260721         4.950.000             70.393,5
# 2                        88287         1.675.215             73.459,1
# 3                    1.264,303         1.336.575             65.442,2
# 4                       324219         1.130.820               57.879
# ..                         ...               ...                  ...
# 97                           8                 9             43.596,5
# 98                          16                 3             28.386,4
# 100                          9                 2                   25
# 101                          6                 1             11.949,8
# 102                          0                 0             83.034,2
#
# [102 rows x 7 columns]

# %%
"SakshiSinghal".replace("a","@")
# Out:
# 'S@kshiSingh@l'

# %%
df.head(2)
# Out:
#    Unnamed: 0 Country      Continent Production (Tons)  \
# 0           0  Brazil  South America       768.678.382
# 1           1   India           Asia       348.448.000
#
#   Production per Person (Kg) Acreage (Hectare) Yield (Kg / Hectare)
# 0                  3.668,531        10.226.205             75.167,5
# 1                     260721         4.950.000             70.393,5

# %%
df.rename(columns = {"Production (Tons)":"Production_tons"}, inplace = True)
df.rename(columns = {"Production per Person (Kg)":"Production_per_person_kg"}, inplace = True)
df.rename(columns = {"Acreage (Hectare)":"Acreage_Hectare"}, inplace = True)
df.rename(columns = {"Yield (Kg / Hectare)":"Yield_kg/hectare"}, inplace = True)
# Out:
# <ipython-input-107-b9b8de44a8de>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns = {"Production (Tons)":"Production_tons"}, inplace = True)
# <ipython-input-107-b9b8de44a8de>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns = {"Production per Person (Kg)":"Production_per_person_kg"}, inplace = True)
# <ipython-input-107-b9b8de44a8de>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns = {"Acreage (Hectare)":"Acreage_Hectare"}, inplace = True)
# <ipython-input-107-b9b8de44a8de>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns = {"Yield (Kg / Hectare)":"Yield_kg/hectare"}, inplace = True)

# %%
df.head()
# Out:
#    Unnamed: 0   Country      Continent Production_tons  \
# 0           0    Brazil  South America     768.678.382
# 1           1     India           Asia     348.448.000
# 2           2     China           Asia     123.059.739
# 3           3  Thailand           Asia      87.468.496
# 4           4  Pakistan           Asia      65.450.704
#
#   Production_per_person_kg Acreage_Hectare Yield_kg/hectare
# 0                3.668,531      10.226.205         75.167,5
# 1                   260721       4.950.000         70.393,5
# 2                    88287       1.675.215         73.459,1
# 3                1.264,303       1.336.575         65.442,2
# 4                   324219       1.130.820           57.879

# %%
df["Production_tons"] = df["Production_tons"].str.replace(".","").astype(float)
# Out:
# <ipython-input-116-1b971ad3c502>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Production_tons"] = df["Production_tons"].str.replace(".","").astype(float)

# %%
df["Production_per_person_kg"] = df["Production_per_person_kg"].str.replace(".","").str.replace(",",".").astype(float)
# Out:
# <ipython-input-120-67a85501d331>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Production_per_person_kg"] = df["Production_per_person_kg"].str.replace(".","").str.replace(",",".").astype(float)

# %%
df["Acreage_Hectare"] = df["Acreage_Hectare"].str.replace(".","").astype(float)
df["Yield_kg/hectare"] = df["Yield_kg/hectare"].str.replace(".","").str.replace(",",".").astype(float)
# Out:
# <ipython-input-121-4677bc3aca44>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Acreage_Hectare"] = df["Acreage_Hectare"].str.replace(".","").astype(float)
# <ipython-input-121-4677bc3aca44>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Yield_kg/hectare"] = df["Yield_kg/hectare"].str.replace(".","").str.replace(",",".").astype(float)

# %%
df.head()
# Out:
#    Unnamed: 0   Country      Continent  Production_tons  \
# 0           0    Brazil  South America      768678382.0
# 1           1     India           Asia      348448000.0
# 2           2     China           Asia      123059739.0
# 3           3  Thailand           Asia       87468496.0
# 4           4  Pakistan           Asia       65450704.0
#
#    Production_per_person_kg  Acreage_Hectare  Yield_kg/hectare
# 0                  3668.531       10226205.0           75167.5
# 1                260721.000        4950000.0           70393.5
# 2                 88287.000        1675215.0           73459.1
# 3                  1264.303        1336575.0           65442.2
# 4                324219.000        1130820.0           57879.0

# %%
df.describe()
# Out:
#        Unnamed: 0  Production_tons  Production_per_person_kg  Acreage_Hectare  \
# count  102.000000     1.020000e+02                102.000000     1.020000e+02
# mean    50.529412     1.850372e+07             112952.435755     2.498981e+05
# std     29.638985     8.419149e+07             176651.341929     1.137003e+06
# min      0.000000     1.000000e+00                  0.000000     0.000000e+00
# 25%     25.250000     6.251875e+04               3671.910000     1.104000e+03
# 50%     50.500000     1.440044e+06              25572.500000     1.655800e+04
# 75%     75.750000     6.426824e+06             146384.750000     8.047400e+04
# max    102.000000     7.686784e+08             951087.000000     1.022620e+07
#
#        Yield_kg/hectare
# count        102.000000
# mean       52628.078431
# std        30504.676683
# min           10.000000
# 25%        29072.025000
# 50%        54108.950000
# 75%        73282.700000
# max       129049.300000

# %%
df[df["Continent"] != "Asia"]
# Out:
#      Unnamed: 0              Country      Continent  Production_tons  \
# 0             0               Brazil  South America      768678382.0
# 5             5               Mexico  North America       56446821.0
# 6             6             Colombia  South America       36951213.0
# 7             7            Australia        Oceania       34403004.0
# 8             8            Guatemala  North America       33533403.0
# ..          ...                  ...            ...              ...
# 92           92             Portugal         Europe           5429.0
# 93           93  Antigua and Barbuda  North America           5365.0
# 94           94             Dominica  North America           4855.0
# 97           97                Spain         Europe            394.0
# 101         101                Samoa        Oceania             12.0
#
#      Production_per_person_kg  Acreage_Hectare  Yield_kg/hectare
# 0                    3668.531       10226205.0           75167.5
# 5                  452524.000         781054.0            7227.0
# 6                  740075.000         416626.0           88691.5
# 7                    1373.406         447204.0           76929.1
# 8                    1938.114          25985.0          129049.3
# ..                        ...              ...               ...
# 92                    528.000             62.0           88274.4
# 93                   6217.000             83.0           64638.6
# 94                  68099.000            244.0           19914.4
# 97                      8.000              9.0           43596.5
# 101                     6.000              1.0           11949.8
#
# [77 rows x 7 columns]

# %%
df = df.drop("Unnamed: 0",axis = 1)

# %%
df.sort_values("Continent", ascending = False )
# Out:
#                      Country      Continent  Production_tons  \
# 0                     Brazil  South America      768678382.0
# 12                 Argentina  South America       21990823.0
# 37                 Venezuela  South America        3331252.0
# 25                  Paraguay  South America        6708000.0
# 43                    Guyana  South America        2394553.0
# ..                       ...            ...              ...
# 54                  Cameroon         Africa        1288732.0
# 76  Central African Republic         Africa         103002.0
# 53                   Nigeria         Africa        1337572.0
# 78                    Rwanda         Africa          93823.0
# 66                      Mali         Africa         365119.0
#
#     Production_per_person_kg  Acreage_Hectare  Yield_kg/hectare
# 0                   3668.531       10226205.0           75167.5
# 12                494237.000         331699.0           66297.5
# 37                104664.000           5223.0           63780.4
# 25                951087.000            120.0             559.0
# 43                  3061.207          44311.0           54039.7
# ..                       ...              ...               ...
# 54                 54162.000         135984.0            9477.1
# 76                 21742.000          18466.0            5577.8
# 53                  6776.000          82586.0           16196.1
# 78                  7818.000           1103.0            8506.3
# 66                 19108.000           5035.0           72521.1
#
# [102 rows x 6 columns]
